# %% [markdown]
# # Checkpoint 1

# %% [markdown]
# Reminder:
#
# - You are being evaluated for compeletion and effort in this checkpoint.
# - Avoid manual labor / hard coding as much as possible, everything we've taught you so far are meant to simplify and automate your process.

# %% [markdown]
# We will be working with the same `states_edu.csv` that you should already be familiar with from the tutorial.
#
# We investigated Grade 8 reading score in the tutorial. For this checkpoint, you are asked to investigate another test. Here's an overview:
#
# * Choose a specific response variable to focus on
# >Grade 4 Math, Grade 4 Reading, Grade 8 Math
# * Pick or create features to use
# >Will all the features be useful in predicting test score? Are some more important than others? Should you standardize, bin, or scale the data?
# * Explore the data as it relates to that test
# >Create at least 2 visualizations (graphs), each with a caption describing the graph and what it tells us about the data
# * Create training and testing data
# >Do you want to train on all the data? Only data from the last 10 years? Only Michigan data?
# * Train a ML model to predict outcome
# >Define what you want to predict, and pick a model in sklearn to use (see sklearn <a href="https://scikit-learn.org/stable/modules/linear_model.html">regressors</a>.
# * Summarize your findings
# >Write a 1 paragraph summary of what you did and make a recommendation about if and how student performance can be predicted
#
# Include comments throughout your code! Every cleanup and preprocessing task should be documented.
#
# Of course, if you're finding this assignment interesting (and we really hope you do!), you are welcome to do more than the requirements! For example, you may want to see if expenditure affects 4th graders more than 8th graders. Maybe you want to look into the extended version of this dataset and see how factors like sex and race are involved. You can include all your work in this notebook when you turn it in -- just always make sure you explain what you did and interpret your results. Good luck!

# %% [markdown]
# <h2> Data Cleanup </h2>
#
# Import `numpy`, `pandas`, and `matplotlib`.
#
# (Feel free to import other libraries!)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Load in the "states_edu.csv" dataset and take a look at the head of the data

# %%
df = pd.read_csv('../data/states_edu.csv')
df_=df.set_index('STATE')
df_.head()
# Out:
#                 PRIMARY_KEY  YEAR  ENROLL  TOTAL_REVENUE  FEDERAL_REVENUE  \
# STATE
# ALABAMA        1992_ALABAMA  1992     NaN      2678885.0         304177.0
# ALASKA          1992_ALASKA  1992     NaN      1049591.0         106780.0
# ARIZONA        1992_ARIZONA  1992     NaN      3258079.0         297888.0
# ARKANSAS      1992_ARKANSAS  1992     NaN      1711959.0         178571.0
# CALIFORNIA  1992_CALIFORNIA  1992     NaN     26260025.0        2072470.0
#
#             STATE_REVENUE  LOCAL_REVENUE  TOTAL_EXPENDITURE  \
# STATE
# ALABAMA         1659028.0       715680.0          2653798.0
# ALASKA           720711.0       222100.0           972488.0
# ARIZONA         1369815.0      1590376.0          3401580.0
# ARKANSAS         958785.0       574603.0          1743022.0
# CALIFORNIA     16546514.0      7641041.0         27138832.0
#
#             INSTRUCTION_EXPENDITURE  SUPPORT_SERVICES_EXPENDITURE  ...  \
# STATE                                                              ...
# ALABAMA                   1481703.0                      735036.0  ...
# ALASKA                     498362.0                      350902.0  ...
# ARIZONA                   1435908.0                     1007732.0  ...
# ARKANSAS                   964323.0                      483488.0  ...
# CALIFORNIA               14358922.0                     8520926.0  ...
#
#             GRADES_4_G  GRADES_8_G  GRADES_12_G  GRADES_1_8_G  GRADES_9_12_G  \
# STATE
# ALABAMA        57948.0     58025.0      41167.0           NaN            NaN
# ALASKA          9748.0      8789.0       6714.0           NaN            NaN
# ARIZONA        55433.0     49081.0      37410.0           NaN            NaN
# ARKANSAS       34632.0     36011.0      27651.0           NaN            NaN
# CALIFORNIA    418418.0    363296.0     270675.0           NaN            NaN
#
#             GRADES_ALL_G  AVG_MATH_4_SCORE  AVG_MATH_8_SCORE  \
# STATE
# ALABAMA         731634.0             208.0             252.0
# ALASKA          122487.0               NaN               NaN
# ARIZONA         673477.0             215.0             265.0
# ARKANSAS        441490.0             210.0             256.0
# CALIFORNIA     5254844.0             208.0             261.0
#
#             AVG_READING_4_SCORE  AVG_READING_8_SCORE
# STATE
# ALABAMA                   207.0                  NaN
# ALASKA                      NaN                  NaN
# ARIZONA                   209.0                  NaN
# ARKANSAS                  211.0                  NaN
# CALIFORNIA                202.0                  NaN
#
# [5 rows x 24 columns]

# %% [markdown]
# You should always familiarize yourself with what each column in the dataframe represents. Read about the states_edu dataset here: https://www.kaggle.com/noriuk/us-education-datasets-unification-project

# %% [markdown]
# Use this space to rename columns, deal with missing data, etc. _(optional)_

# %%
df_.rename({
    'GRADES_PK_G':'ENROLL_PREK',
    'GRADES_KG_G':'ENROLL_KINDER',
    'GRADES_4_G':'ENROLL_4',
    'GRADES_8_G':'ENROLL_8',
    'GRADES_12_G':'ENROLL_12',
    'GRADES_1_8_G':'ENROLL_PRIMARY',
    'GRADES_9_12_G':'ENROLL_HS',
    'GRADES_ALL_G':'ENROLL_ALL',
    'ENROLL':'ENROLL_ALL_CB'
    },
    axis=1,inplace=True)
df_.dropna(subset=['AVG_MATH_8_SCORE'], inplace=True)
df_["ENROLL_ALL"].isna().sum()
(df_["ENROLL_ALL"]-df_["ENROLL_PREK"]-df_["ENROLL_KINDER"]-df_["ENROLL_PRIMARY"]-df_["ENROLL_HS"]).describe()
df_["ENROLL_ALL_CB"] = df_["ENROLL_ALL_CB"].fillna(df_["ENROLL_ALL"])
# Out:
#                                     PRIMARY_KEY  YEAR  ENROLL_ALL_CB  \
# STATE
# ALABAMA                            1992_ALABAMA  1992       731634.0
# ARIZONA                            1992_ARIZONA  1992       673477.0
# ARKANSAS                          1992_ARKANSAS  1992       441490.0
# CALIFORNIA                      1992_CALIFORNIA  1992      5254844.0
# COLORADO                          1992_COLORADO  1992       612635.0
# CONNECTICUT                    1992_CONNECTICUT  1992       488476.0
# DELAWARE                          1992_DELAWARE  1992       104321.0
# DISTRICT_OF_COLUMBIA  1992_DISTRICT_OF_COLUMBIA  1992        80937.0
# FLORIDA                            1992_FLORIDA  1992      1981407.0
# GEORGIA                            1992_GEORGIA  1992      1207186.0
#
#                       TOTAL_REVENUE  FEDERAL_REVENUE  STATE_REVENUE  \
# STATE
# ALABAMA                   2678885.0         304177.0      1659028.0
# ARIZONA                   3258079.0         297888.0      1369815.0
# ARKANSAS                  1711959.0         178571.0       958785.0
# CALIFORNIA               26260025.0        2072470.0     16546514.0
# COLORADO                  3185173.0         163253.0      1307986.0
# CONNECTICUT               3834302.0         143542.0      1342539.0
# DELAWARE                   645233.0          45945.0       420942.0
# DISTRICT_OF_COLUMBIA       709480.0          64749.0            0.0
# FLORIDA                  11506299.0         788420.0      5683949.0
# GEORGIA                   5536901.0         398701.0      2798674.0
#
#                       LOCAL_REVENUE  TOTAL_EXPENDITURE  \
# STATE
# ALABAMA                    715680.0          2653798.0
# ARIZONA                   1590376.0          3401580.0
# ARKANSAS                   574603.0          1743022.0
# CALIFORNIA                7641041.0         27138832.0
# COLORADO                  1713934.0          3264826.0
# CONNECTICUT               2348221.0          3721338.0
# DELAWARE                   178346.0           638784.0
# DISTRICT_OF_COLUMBIA       644731.0           742893.0
# FLORIDA                   5033930.0         11305642.0
# GEORGIA                   2339526.0          5535942.0
#
#                       INSTRUCTION_EXPENDITURE  SUPPORT_SERVICES_EXPENDITURE  \
# STATE
# ALABAMA                             1481703.0                      735036.0
# ARIZONA                             1435908.0                     1007732.0
# ARKANSAS                             964323.0                      483488.0
# CALIFORNIA                         14358922.0                     8520926.0
# COLORADO                            1642466.0                     1035970.0
# CONNECTICUT                         2148041.0                     1142600.0
# DELAWARE                             372722.0                      194915.0
# DISTRICT_OF_COLUMBIA                 329160.0                      316679.0
# FLORIDA                             5166374.0                     3410440.0
# GEORGIA                             3043984.0                     1559059.0
#
#                       ...  ENROLL_4  ENROLL_8  ENROLL_12  ENROLL_PRIMARY  \
# STATE                 ...
# ALABAMA               ...   57948.0   58025.0    41167.0             NaN
# ARIZONA               ...   55433.0   49081.0    37410.0             NaN
# ARKANSAS              ...   34632.0   36011.0    27651.0             NaN
# CALIFORNIA            ...  418418.0  363296.0   270675.0             NaN
# COLORADO              ...   50648.0   45025.0    34533.0             NaN
# CONNECTICUT           ...   38058.0   33691.0    28366.0             NaN
# DELAWARE              ...    8272.0    8012.0     6129.0             NaN
# DISTRICT_OF_COLUMBIA  ...    5832.0    5000.0     3433.0             NaN
# FLORIDA               ...  164416.0  142372.0   100835.0             NaN
# GEORGIA               ...   99648.0   92374.0    63646.0             NaN
#
#                       ENROLL_HS  ENROLL_ALL  AVG_MATH_4_SCORE  \
# STATE
# ALABAMA                     NaN    731634.0             208.0
# ARIZONA                     NaN    673477.0             215.0
# ARKANSAS                    NaN    441490.0             210.0
# CALIFORNIA                  NaN   5254844.0             208.0
# COLORADO                    NaN    612635.0             221.0
# CONNECTICUT                 NaN    488476.0             227.0
# DELAWARE                    NaN    104321.0             218.0
# DISTRICT_OF_COLUMBIA        NaN     80937.0             193.0
# FLORIDA                     NaN   1981407.0             214.0
# GEORGIA                     NaN   1207186.0             216.0
#
#                       AVG_MATH_8_SCORE  AVG_READING_4_SCORE  \
# STATE
# ALABAMA                          252.0                207.0
# ARIZONA                          265.0                209.0
# ARKANSAS                         256.0                211.0
# CALIFORNIA                       261.0                202.0
# COLORADO                         272.0                217.0
# CONNECTICUT                      274.0                222.0
# DELAWARE                         263.0                213.0
# DISTRICT_OF_COLUMBIA             235.0                188.0
# FLORIDA                          260.0                208.0
# GEORGIA                          259.0                212.0
#
#                       AVG_READING_8_SCORE
# STATE
# ALABAMA                               NaN
# ARIZONA                               NaN
# ARKANSAS                              NaN
# CALIFORNIA                            NaN
# COLORADO                              NaN
# CONNECTICUT                           NaN
# DELAWARE                              NaN
# DISTRICT_OF_COLUMBIA                  NaN
# FLORIDA                               NaN
# GEORGIA                               NaN
#
# [10 rows x 24 columns]

# %% [markdown]
# <h2>Exploratory Data Analysis (EDA) </h2>

# %% [markdown]
# Chosen Outcome Variable for Test: GRADE 8 MATH

# %% [markdown]
# How many years of data are logged in our dataset?

# %%
print(df_["YEAR"].unique())
print(df_["YEAR"].nunique())
# Out:
# [1992 2000 2003 2005 2007 2009 2011 2013 2015 1990 2017 1996 2019]
# 13

# %% [markdown]
# Let's compare Michigan to Ohio. Which state has the higher average outcome score across all years?

# %%
#state = df_.groupby("STATE")
#state
#state["AVG_MATH_8_SCORE"].mean()
#or...
#wasn't able to pull up both MI and OH avg_math_8_score simultaneously, so ran each code individually to get result
#df_.loc["MICHIGAN",["AVG_MATH_8_SCORE"]].mean() #MI 276.1667
df_.loc["OHIO",["AVG_MATH_8_SCORE"]].mean() #OH 282.23
# Out:
# AVG_MATH_8_SCORE    282.25
# dtype: float64

# %% [markdown]
# Find the average for your outcome score across all states in 2019

# %%
# Out:
#              PRIMARY_KEY          STATE  ENROLL  TOTAL_REVENUE  \
# YEAR
# 1992        1992_ALABAMA        ALABAMA     NaN      2678885.0
# 1992         1992_ALASKA         ALASKA     NaN      1049591.0
# 1992        1992_ARIZONA        ARIZONA     NaN      3258079.0
# 1992       1992_ARKANSAS       ARKANSAS     NaN      1711959.0
# 1992     1992_CALIFORNIA     CALIFORNIA     NaN     26260025.0
# ...                  ...            ...     ...            ...
# 2019       2019_VIRGINIA       VIRGINIA     NaN            NaN
# 2019     2019_WASHINGTON     WASHINGTON     NaN            NaN
# 2019  2019_WEST_VIRGINIA  WEST_VIRGINIA     NaN            NaN
# 2019      2019_WISCONSIN      WISCONSIN     NaN            NaN
# 2019        2019_WYOMING        WYOMING     NaN            NaN
#
#       FEDERAL_REVENUE  STATE_REVENUE  LOCAL_REVENUE  TOTAL_EXPENDITURE  \
# YEAR
# 1992         304177.0      1659028.0       715680.0          2653798.0
# 1992         106780.0       720711.0       222100.0           972488.0
# 1992         297888.0      1369815.0      1590376.0          3401580.0
# 1992         178571.0       958785.0       574603.0          1743022.0
# 1992        2072470.0     16546514.0      7641041.0         27138832.0
# ...               ...            ...            ...                ...
# 2019              NaN            NaN            NaN                NaN
# 2019              NaN            NaN            NaN                NaN
# 2019              NaN            NaN            NaN                NaN
# 2019              NaN            NaN            NaN                NaN
# 2019              NaN            NaN            NaN                NaN
#
#       INSTRUCTION_EXPENDITURE  SUPPORT_SERVICES_EXPENDITURE  ...  GRADES_4_G  \
# YEAR                                                         ...
# 1992                1481703.0                      735036.0  ...     57948.0
# 1992                 498362.0                      350902.0  ...      9748.0
# 1992                1435908.0                     1007732.0  ...     55433.0
# 1992                 964323.0                      483488.0  ...     34632.0
# 1992               14358922.0                     8520926.0  ...    418418.0
# ...                       ...                           ...  ...         ...
# 2019                      NaN                           NaN  ...         NaN
# 2019                      NaN                           NaN  ...         NaN
# 2019                      NaN                           NaN  ...         NaN
# 2019                      NaN                           NaN  ...         NaN
# 2019                      NaN                           NaN  ...         NaN
#
#       GRADES_8_G  GRADES_12_G  GRADES_1_8_G  GRADES_9_12_G  GRADES_ALL_G  \
# YEAR
# 1992     58025.0      41167.0           NaN            NaN      731634.0
# 1992      8789.0       6714.0           NaN            NaN      122487.0
# 1992     49081.0      37410.0           NaN            NaN      673477.0
# 1992     36011.0      27651.0           NaN            NaN      441490.0
# 1992    363296.0     270675.0           NaN            NaN     5254844.0
# ...          ...          ...           ...            ...           ...
# 2019         NaN          NaN           NaN            NaN           NaN
# 2019         NaN          NaN           NaN            NaN           NaN
# 2019         NaN          NaN           NaN            NaN           NaN
# 2019         NaN          NaN           NaN            NaN           NaN
# 2019         NaN          NaN           NaN            NaN           NaN
#
#       AVG_MATH_4_SCORE  AVG_MATH_8_SCORE  AVG_READING_4_SCORE  \
# YEAR
# 1992             208.0             252.0                207.0
# 1992               NaN               NaN                  NaN
# 1992             215.0             265.0                209.0
# 1992             210.0             256.0                211.0
# 1992             208.0             261.0                202.0
# ...                ...               ...                  ...
# 2019             247.0             287.0                224.0
# 2019             240.0             286.0                220.0
# 2019             231.0             272.0                213.0
# 2019             242.0             289.0                220.0
# 2019             246.0             286.0                227.0
#
#       AVG_READING_8_SCORE
# YEAR
# 1992                  NaN
# 1992                  NaN
# 1992                  NaN
# 1992                  NaN
# 1992                  NaN
# ...                   ...
# 2019                262.0
# 2019                266.0
# 2019                256.0
# 2019                267.0
# 2019                265.0
#
# [1715 rows x 24 columns]

# %% [markdown]
# Find the maximum outcome score for every state.
#
# Refer to the `Grouping and Aggregating` section in Tutorial 0 if you are stuck.

# %%
state["AVG_MATH_8_SCORE"].max()
# Out:
# STATE
# ALABAMA                 269.0
# ALASKA                  283.0
# ARIZONA                 283.0
# ARKANSAS                279.0
# CALIFORNIA              277.0
# COLORADO                292.0
# CONNECTICUT             289.0
# DELAWARE                284.0
# DISTRICT_OF_COLUMBIA    269.0
# DODEA                   293.0
# FLORIDA                 281.0
# GEORGIA                 281.0
# HAWAII                  281.0
# IDAHO                   287.0
# ILLINOIS                285.0
# INDIANA                 288.0
# IOWA                    286.0
# KANSAS                  290.0
# KENTUCKY                282.0
# LOUISIANA               273.0
# MAINE                   289.0
# MARYLAND                288.0
# MASSACHUSETTS           301.0
# MICHIGAN                280.0
# MINNESOTA               295.0
# MISSISSIPPI             274.0
# MISSOURI                286.0
# MONTANA                 293.0
# NATIONAL                285.0
# NEBRASKA                288.0
# NEVADA                  278.0
# NEW_HAMPSHIRE           296.0
# NEW_JERSEY              296.0
# NEW_MEXICO              274.0
# NEW_YORK                283.0
# NORTH_CAROLINA          286.0
# NORTH_DAKOTA            293.0
# OHIO                    290.0
# OKLAHOMA                279.0
# OREGON                  285.0
# PENNSYLVANIA            290.0
# RHODE_ISLAND            284.0
# SOUTH_CAROLINA          282.0
# SOUTH_DAKOTA            291.0
# TENNESSEE               280.0
# TEXAS                   290.0
# UTAH                    287.0
# VERMONT                 295.0
# VIRGINIA                290.0
# WASHINGTON              290.0
# WEST_VIRGINIA           274.0
# WISCONSIN               289.0
# WYOMING                 289.0
# Name: AVG_MATH_8_SCORE, dtype: float64

# %% [markdown]
# <h2> Feature Engineering </h2>
#
# After exploring the data, you can choose to modify features that you would use to predict the performance of the students on your chosen response variable.
#
# You can also create your own features. For example, perhaps you figured that maybe a state's expenditure per student may affect their overall academic performance so you create a expenditure_per_student feature.
#
# Use this space to modify or create features.

# %% [markdown]
# Feature engineering justification: **<BRIEFLY DESCRIBE WHY YOU MADE THE CHANGES THAT YOU DID\>**

# %% [markdown]
# <h2>Visualization</h2>
#
# Investigate the relationship between your chosen response variable and at least two predictors using visualizations. Write down your observations.
#
# **Visualization 1**

# %% [markdown]
# **<CAPTION FOR VIZ 1>**

# %% [markdown]
# **Visualization 2**

# %% [markdown]
# **<CAPTION FOR VIZ 2>**

# %% [markdown]
# <h2> Data Creation </h2>
#
# _Use this space to create train/test data_

# %%
from sklearn.model_selection import train_test_split

# %%
# X =
# y =

# %%
# X_train, X_test, y_train, y_test = train_test_split(
#      X, y, test_size=, random_state=42)

# %% [markdown]
# <h2> Prediction </h2>

# %% [markdown]
# ML Models [Resource](https://medium.com/@vijaya.beeravalli/comparison-of-machine-learning-classification-models-for-credit-card-default-data-c3cf805c9a5a)

# %%
# import your sklearn class here

# %%
# create your model here
# model =

# %%
model.fit(X_train, y_train)

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# ## Evaluation

# %% [markdown]
# Choose some metrics to evaluate the performance of your model, some of them are mentioned in the tutorial.

# %% [markdown]
# We have copied over the graphs that visualize the model's performance on the training and testing set.
#
# Change `col_name` and modify the call to `plt.ylabel()` to isolate how a single predictor affects the model.

# %%
# col_name = 'COLUMN NAME OF ONE PREDICTOR'

# f = plt.figure(figsize=(12,6))
# plt.scatter(X_train[col_name], y_train, color = "red")
# plt.scatter(X_train[col_name], model.predict(X_train), color = "green")

# plt.legend(['True Training','Predicted Training'])
# plt.xlabel(col_name)
# plt.ylabel('NAME OF THE PREDICTOR')
# plt.title("Model Behavior On Training Set")

# %%
# col_name = 'COLUMN NAME OF ONE PREDICTOR"

# f = plt.figure(figsize=(12,6))
# plt.scatter(X_test[col_name], y_test, color = "blue")
# plt.scatter(X_test[col_name], model.predict(X_test), color = "black")

# plt.legend(['True testing','Predicted testing'])
# plt.xlabel(col_name)
# plt.ylabel('NAME OF THE PREDICTOR')
# plt.title("Model Behavior on Testing Set")

# %% [markdown]
# <h2> Summary </h2>

# %% [markdown]
# **<WRITE A PARAGRAPH SUMMARIZING YOUR WORK, FINDINGS, AND THE PERFORMANCE OF YOUR MODEL\>**
